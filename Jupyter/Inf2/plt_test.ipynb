# %%
# %matplotlib widget
import matplotlib.pyplot as plt
import numpy as np

# %%
X = np.linspace(-2, 2, 100)
y = X**2

# %%
fig = plt.figure()
ax = fig.add_subplot();
ax.axis('equal')
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
n=1000
X = np.random.uniform(-1, 1, n)
y = np.random.uniform(-1, 1, n)
hit = X**2 + y**2 <= 1
pi = hit.sum()/n * 4

# %%
k = np.linspace(0, 2*np.pi, 1000)
ax.fill_between(np.sin(k), np.cos(k), c='orange')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
